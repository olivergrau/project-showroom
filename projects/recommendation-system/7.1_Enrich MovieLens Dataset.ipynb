# %%
import pandas as pd
import requests
import os
import json
from time import sleep

# Load links.csv
links_path = 'data/ml-32m/links.csv'
links = pd.read_csv(links_path)

# TMDb API setup
TMDB_API_KEY = "04826aaa5a7349d28828c140963b6483"
BASE_URL = "https://api.themoviedb.org/3/movie/"

# Directory to save fetched data
output_dir = "data/enriched"
os.makedirs(output_dir, exist_ok=True)

# Function to fetch movie data from TMDb API
def fetch_movie_data(tmdb_id):
    url = f"{BASE_URL}{tmdb_id}"
    params = {"api_key": TMDB_API_KEY, "language": "en-US"}
    try:
        response = requests.get(url, params=params)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data for TMDb ID {tmdb_id}: {e}")
        return None

# Fetch and save data
for _, row in links.iterrows():
    tmdb_id = row['tmdbId']
    if pd.isna(tmdb_id):
        continue
    
    output_file = os.path.join(output_dir, f"{int(tmdb_id)}.json")
    if os.path.exists(output_file):
        print(f"Data for TMDb ID {tmdb_id} already exists. Skipping.")
        continue

    #print(f"Fetching data for TMDb ID {tmdb_id}...")
    movie_data = fetch_movie_data(int(tmdb_id))
    if movie_data:
        with open(output_file, 'w') as f:
            json.dump(movie_data, f)
    sleep(0.005)  # Avoid hitting rate limits
# Out:
# Data for TMDb ID 862.0 already exists. Skipping.
# Data for TMDb ID 8844.0 already exists. Skipping.
# Data for TMDb ID 15602.0 already exists. Skipping.
# Data for TMDb ID 31357.0 already exists. Skipping.
# Data for TMDb ID 11862.0 already exists. Skipping.
# Data for TMDb ID 949.0 already exists. Skipping.
# Data for TMDb ID 11860.0 already exists. Skipping.
# Data for TMDb ID 45325.0 already exists. Skipping.
# Data for TMDb ID 9091.0 already exists. Skipping.
# Data for TMDb ID 710.0 already exists. Skipping.
# Data for TMDb ID 9087.0 already exists. Skipping.
# Data for TMDb ID 12110.0 already exists. Skipping.
# Data for TMDb ID 21032.0 already exists. Skipping.
# Data for TMDb ID 10858.0 already exists. Skipping.
# Data for TMDb ID 1408.0 already exists. Skipping.
# Data for TMDb ID 524.0 already exists. Skipping.
# Data for TMDb ID 4584.0 already exists. Skipping.
# Data for TMDb ID 5.0 already exists. Skipping.
# Data for TMDb ID 9273.0 already exists. Skipping.
# Data for TMDb ID 11517.0 already exists. Skipping.
# Data for TMDb ID 8012.0 already exists. Skipping.
# Data for TMDb ID 1710.0 already exists. Skipping.
# Data for TMDb ID 9691.0 already exists. Skipping.
# Data for TMDb ID 12665.0 already exists. Skipping.
# Data for TMDb ID 451.0 already exists. Skipping.
# Data for TMDb ID 16420.0 already exists. Skipping.
# Data for TMDb ID 9263.0 already exists. Skipping.
# Data for TMDb ID 17015.0 already exists. Skipping.
# Data for TMDb ID 902.0 already exists. Skipping.
# Data for TMDb ID 37557.0 already exists. Skipping.
# Data for TMDb ID 9909.0 already exists. Skipping.
# Data for TMDb ID 63.0 already exists. Skipping.
# Data for TMDb ID 78802.0 already exists. Skipping.
# Data for TMDb ID 9598.0 already exists. Skipping.
# Data for TMDb ID 47018.0 already exists. Skipping.
# Data for TMDb ID 687.0 already exists. Skipping.
# Data for TMDb ID 139405.0 already exists. Skipping.
# Data for TMDb ID 33689.0 already exists. Skipping.
# Data for TMDb ID 9603.0 already exists. Skipping.
# Data for TMDb ID 34615.0 already exists. Skipping.
# Data for TMDb ID 31174.0 already exists. Skipping.
# Data for TMDb ID 11443.0 already exists. Skipping.
# Data for TMDb ID 35196.0 already exists. Skipping.
# Data for TMDb ID 9312.0 already exists. Skipping.
# Data for TMDb ID 577.0 already exists. Skipping.
# Data for TMDb ID 11861.0 already exists. Skipping.
# Data for TMDb ID 807.0 already exists. Skipping.
# Data for TMDb ID 10530.0 already exists. Skipping.
# Data for TMDb ID 8391.0 already exists. Skipping.
# Data for TMDb ID 629.0 already exists. Skipping.
# Data for TMDb ID 117164.0 already exists. Skipping.
# Data for TMDb ID 11448.0 already exists. Skipping.
# Data for TMDb ID 49133.0 already exists. Skipping.
# Data for TMDb ID 26441.0 already exists. Skipping.
# Data for TMDb ID 97406.0 already exists. Skipping.
# Data for TMDb ID 124057.0 already exists. Skipping.
# Data for TMDb ID 9089.0 already exists. Skipping.
# Data for TMDb ID 11010.0 already exists. Skipping.
# Data for TMDb ID 99040.0 already exists. Skipping.
# Data for TMDb ID 11359.0 already exists. Skipping.
# Data for TMDb ID 17182.0 already exists. Skipping.
# Data for TMDb ID 2054.0 already exists. Skipping.
# Data for TMDb ID 10607.0 already exists. Skipping.
# Data for TMDb ID 19760.0 already exists. Skipping.
# Data for TMDb ID 9536.0 already exists. Skipping.
# Data for TMDb ID 11525.0 already exists. Skipping.
# Data for TMDb ID 40628.0 already exists. Skipping.
# Data for TMDb ID 4482.0 already exists. Skipping.
# Data for TMDb ID 10634.0 already exists. Skipping.
# Data for TMDb ID 755.0 already exists. Skipping.
# Data for TMDb ID 11859.0 already exists. Skipping.
# Data for TMDb ID 28387.0 already exists. Skipping.
# Data for TMDb ID 48750.0 already exists. Skipping.
# Data for TMDb ID 20927.0 already exists. Skipping.
# Data for TMDb ID 36929.0 already exists. Skipping.
# Data for TMDb ID 9102.0 already exists. Skipping.
# Data for TMDb ID 124626.0 already exists. Skipping.
# Data for TMDb ID 27526.0 already exists. Skipping.
# Data for TMDb ID 9623.0 already exists. Skipping.
# Data for TMDb ID 46785.0 already exists. Skipping.
# Data for TMDb ID 400.0 already exists. Skipping.
# Data for TMDb ID 880.0 already exists. Skipping.
# Data for TMDb ID 146599.0 already exists. Skipping.
# Data for TMDb ID 188588.0 already exists. Skipping.
# Data for TMDb ID 8447.0 already exists. Skipping.
# Data for TMDb ID 10534.0 already exists. Skipping.
# Data for TMDb ID 17414.0 already exists. Skipping.
# Data for TMDb ID 13997.0 already exists. Skipping.
# Data for TMDb ID 2086.0 already exists. Skipping.
# Data for TMDb ID 61548.0 already exists. Skipping.
# Data for TMDb ID 9095.0 already exists. Skipping.
# Data for TMDb ID 12158.0 already exists. Skipping.
# Data for TMDb ID 9283.0 already exists. Skipping.
# Data for TMDb ID 9208.0 already exists. Skipping.
# Data for TMDb ID 40154.0 already exists. Skipping.
# Data for TMDb ID 406.0 already exists. Skipping.
# Data for TMDb ID 45549.0 already exists. Skipping.
# Data for TMDb ID 63076.0 already exists. Skipping.
# Data for TMDb ID 11062.0 already exists. Skipping.
# Data for TMDb ID 13685.0 already exists. Skipping.
# Data for TMDb ID 47475.0 already exists. Skipping.
# Data for TMDb ID 2045.0 already exists. Skipping.
# Data for TMDb ID 9614.0 already exists. Skipping.
# Data for TMDb ID 688.0 already exists. Skipping.
# Data for TMDb ID 11907.0 already exists. Skipping.
# Data for TMDb ID 10874.0 already exists. Skipping.
# Data for TMDb ID 89333.0 already exists. Skipping.
# Data for TMDb ID 96357.0 already exists. Skipping.
# Data for TMDb ID 197.0 already exists. Skipping.
# Data for TMDb ID 103.0 already exists. Skipping.
# Data for TMDb ID 33542.0 already exists. Skipping.
# Data for TMDb ID 43566.0 already exists. Skipping.
# Data for TMDb ID 71754.0 already exists. Skipping.
# Data for TMDb ID 43612.0 already exists. Skipping.
# Data for TMDb ID 51352.0 already exists. Skipping.
# Data for TMDb ID 16934.0 already exists. Skipping.
# Data for TMDb ID 10324.0 already exists. Skipping.
# Data for TMDb ID 78406.0 already exists. Skipping.
# Data for TMDb ID 55731.0 already exists. Skipping.
# Data for TMDb ID 32119.0 already exists. Skipping.
# Data for TMDb ID 11066.0 already exists. Skipping.
# Data for TMDb ID 11104.0 already exists. Skipping.
# Data for TMDb ID 37975.0 already exists. Skipping.
# Data for TMDb ID 2074.0 already exists. Skipping.
# Data for TMDb ID 27793.0 already exists. Skipping.
# Data for TMDb ID 44284.0 already exists. Skipping.
# Data for TMDb ID 290157.0 already exists. Skipping.
# Data for TMDb ID 110972.0 already exists. Skipping.
# Data for TMDb ID 32622.0 already exists. Skipping.
# Data for TMDb ID 73067.0 already exists. Skipping.
# Data for TMDb ID 11863.0 already exists. Skipping.
# Data for TMDb ID 55475.0 already exists. Skipping.
# Data for TMDb ID 124636.0 already exists. Skipping.
# Data for TMDb ID 9101.0 already exists. Skipping.
# Data for TMDb ID 123360.0 already exists. Skipping.
# Data for TMDb ID 5757.0 already exists. Skipping.
# Data for TMDb ID 39428.0 already exists. Skipping.
# Data for TMDb ID 124639.0 already exists. Skipping.
# Data for TMDb ID 9302.0 already exists. Skipping.
# Data for TMDb ID 11000.0 already exists. Skipping.
# Data for TMDb ID 525153.0 already exists. Skipping.
# Data for TMDb ID 249882.0 already exists. Skipping.
# Data for TMDb ID 16388.0 already exists. Skipping.
# Data for TMDb ID 9737.0 already exists. Skipping.
# Data for TMDb ID 30765.0 already exists. Skipping.
# Data for TMDb ID 10474.0 already exists. Skipping.
# Data for TMDb ID 22279.0 already exists. Skipping.
# Data for TMDb ID 30157.0 already exists. Skipping.
# Data for TMDb ID 568.0 already exists. Skipping.
# Data for TMDb ID 11780.0 already exists. Skipping.
# Data for TMDb ID 34996.0 already exists. Skipping.
# Data for TMDb ID 414.0 already exists. Skipping.
# Data for TMDb ID 649.0 already exists. Skipping.
# Data for TMDb ID 1873.0 already exists. Skipping.
# Data for TMDb ID 5894.0 already exists. Skipping.
# Data for TMDb ID 1775.0 already exists. Skipping.
# Data for TMDb ID 8839.0 already exists. Skipping.
# Data for TMDb ID 20649.0 already exists. Skipping.
# Data for TMDb ID 10329.0 already exists. Skipping.
# Data for TMDb ID 8963.0 already exists. Skipping.
# Data for TMDb ID 26564.0 already exists. Skipping.
# Data for TMDb ID 8068.0 already exists. Skipping.
# Data for TMDb ID 8512.0 already exists. Skipping.
# Data for TMDb ID 1572.0 already exists. Skipping.
# Data for TMDb ID 13552.0 already exists. Skipping.
# Data for TMDb ID 259209.0 already exists. Skipping.
# Data for TMDb ID 6520.0 already exists. Skipping.
# Data for TMDb ID 9073.0 already exists. Skipping.
# Data for TMDb ID 10428.0 already exists. Skipping.
# Data for TMDb ID 17447.0 already exists. Skipping.
# Data for TMDb ID 9886.0 already exists. Skipping.
# Data for TMDb ID 9482.0 already exists. Skipping.
# Data for TMDb ID 19326.0 already exists. Skipping.
# Data for TMDb ID 9344.0 already exists. Skipping.
# Data for TMDb ID 9071.0 already exists. Skipping.
# Data for TMDb ID 8973.0 already exists. Skipping.
# Data for TMDb ID 15730.0 already exists. Skipping.
# Data for TMDb ID 47608.0 already exists. Skipping.
# Data for TMDb ID 2293.0 already exists. Skipping.
# Data for TMDb ID 9070.0 already exists. Skipping.
# Data for TMDb ID 68274.0 already exists. Skipping.
# Data for TMDb ID 48787.0 already exists. Skipping.
# Data for TMDb ID 34574.0 already exists. Skipping.
# Data for TMDb ID 1642.0 already exists. Skipping.
# Data for TMDb ID 11472.0 already exists. Skipping.
# Data for TMDb ID 36196.0 already exists. Skipping.
# Data for TMDb ID 11980.0 already exists. Skipping.
# Data for TMDb ID 58372.0 already exists. Skipping.
# Data for TMDb ID 32646.0 already exists. Skipping.
# Data for TMDb ID 10533.0 already exists. Skipping.
# Data for TMDb ID 56088.0 already exists. Skipping.
# Data for TMDb ID 10802.0 already exists. Skipping.
# Data for TMDb ID 10149.0 already exists. Skipping.
# Data for TMDb ID 18402.0 already exists. Skipping.
# Data for TMDb ID 9348.0 already exists. Skipping.
# Data for TMDb ID 139408.0 already exists. Skipping.
# Data for TMDb ID 281.0 already exists. Skipping.
# Data for TMDb ID 5967.0 already exists. Skipping.
# Data for TMDb ID 79593.0 already exists. Skipping.
# Data for TMDb ID 47939.0 already exists. Skipping.
# Data for TMDb ID 36834.0 already exists. Skipping.
# Data for TMDb ID 9090.0 already exists. Skipping.
# Data for TMDb ID 3512.0 already exists. Skipping.
# Data for TMDb ID 52856.0 already exists. Skipping.
# Data for TMDb ID 77350.0 already exists. Skipping.
# Data for TMDb ID 9560.0 already exists. Skipping.
# Data for TMDb ID 9804.0 already exists. Skipping.
# Data for TMDb ID 31611.0 already exists. Skipping.
# Data for TMDb ID 65796.0 already exists. Skipping.
# Data for TMDb ID 49805.0 already exists. Skipping.
# Data for TMDb ID 26258.0 already exists. Skipping.
# Data for TMDb ID 50797.0 already exists. Skipping.
# Data for TMDb ID 19155.0 already exists. Skipping.
# Data for TMDb ID 76.0 already exists. Skipping.
# Data for TMDb ID 11017.0 already exists. Skipping.
# Data for TMDb ID 37141.0 already exists. Skipping.
# Data for TMDb ID 9382.0 already exists. Skipping.
# Data for TMDb ID 6715.0 already exists. Skipping.
# Data for TMDb ID 18256.0 already exists. Skipping.
# Data for TMDb ID 22625.0 already exists. Skipping.
# Data for TMDb ID 2292.0 already exists. Skipping.
# Data for TMDb ID 1909.0 already exists. Skipping.
# Data for TMDb ID 8984.0 already exists. Skipping.
# Data for TMDb ID 61813.0 already exists. Skipping.
# Data for TMDb ID 4954.0 already exists. Skipping.
# Data for TMDb ID 62488.0 already exists. Skipping.
# Data for TMDb ID 10531.0 already exists. Skipping.
# Data for TMDb ID 11929.0 already exists. Skipping.
# Data for TMDb ID 8467.0 already exists. Skipping.
# Data for TMDb ID 10451.0 already exists. Skipping.
# Data for TMDb ID 20156.0 already exists. Skipping.
# Data for TMDb ID 18395.0 already exists. Skipping.
# Data for TMDb ID 522.0 already exists. Skipping.
# Data for TMDb ID 397.0 already exists. Skipping.
# Data for TMDb ID 10525.0 already exists. Skipping.
# Data for TMDb ID 27985.0 already exists. Skipping.
# Data for TMDb ID 15789.0 already exists. Skipping.
# Data for TMDb ID 27303.0 already exists. Skipping.
# Data for TMDb ID 21183.0 already exists. Skipping.
# Data for TMDb ID 10954.0 already exists. Skipping.
# Data for TMDb ID 47867.0 already exists. Skipping.
# Data for TMDb ID 43475.0 already exists. Skipping.
# Data for TMDb ID 72031.0 already exists. Skipping.
# Data for TMDb ID 14275.0 already exists. Skipping.
# Data for TMDb ID 1024.0 already exists. Skipping.
# Data for TMDb ID 17207.0 already exists. Skipping.
# Data for TMDb ID 13701.0 already exists. Skipping.
# Data for TMDb ID 14819.0 already exists. Skipping.
# Data for TMDb ID 32631.0 already exists. Skipping.
# Data for TMDb ID 11777.0 already exists. Skipping.
# Data for TMDb ID 628.0 already exists. Skipping.
# Data for TMDb ID 87729.0 already exists. Skipping.
# Data for TMDb ID 18713.0 already exists. Skipping.
# Data for TMDb ID 6280.0 already exists. Skipping.
# Data for TMDb ID 9061.0 already exists. Skipping.
# Data for TMDb ID 37108.0 already exists. Skipping.
# Data for TMDb ID 6071.0 already exists. Skipping.
# Data for TMDb ID 11.0 already exists. Skipping.
# Data for TMDb ID 9587.0 already exists. Skipping.
# Data for TMDb ID 19101.0 already exists. Skipping.
# Data for TMDb ID 49980.0 already exists. Skipping.
# Data for TMDb ID 17961.0 already exists. Skipping.
# Data for TMDb ID 18183.0 already exists. Skipping.
# Data for TMDb ID 4476.0 already exists. Skipping.
# Data for TMDb ID 11008.0 already exists. Skipping.
# Data for TMDb ID 47504.0 already exists. Skipping.
# Data for TMDb ID 32325.0 already exists. Skipping.
# Data for TMDb ID 43742.0 already exists. Skipping.
# Data for TMDb ID 28313.0 already exists. Skipping.
# Data for TMDb ID 11318.0 already exists. Skipping.
# Data for TMDb ID 3036.0 already exists. Skipping.
# Data for TMDb ID 40490.0 already exists. Skipping.
# Data for TMDb ID 24070.0 already exists. Skipping.
# Data for TMDb ID 8986.0 already exists. Skipping.
# Data for TMDb ID 10510.0 already exists. Skipping.
# Data for TMDb ID 17402.0 already exists. Skipping.
# Data for TMDb ID 38722.0 already exists. Skipping.
# Data for TMDb ID 8438.0 already exists. Skipping.
# Data for TMDb ID 11593.0 already exists. Skipping.
# Data for TMDb ID 1945.0 already exists. Skipping.
# Data for TMDb ID 39310.0 already exists. Skipping.
# Data for TMDb ID 109560.0 already exists. Skipping.
# Data for TMDb ID 56428.0 already exists. Skipping.
# Data for TMDb ID 63105.0 already exists. Skipping.
# Data for TMDb ID 131957.0 already exists. Skipping.
# Data for TMDb ID 241.0 already exists. Skipping.
# Data for TMDb ID 9058.0 already exists. Skipping.
# Data for TMDb ID 527.0 already exists. Skipping.
# Data for TMDb ID 6950.0 already exists. Skipping.
# Data for TMDb ID 101.0 already exists. Skipping.
# Data for TMDb ID 63020.0 already exists. Skipping.
# Data for TMDb ID 2307.0 already exists. Skipping.
# Data for TMDb ID 680.0 already exists. Skipping.
# Data for TMDb ID 41478.0 already exists. Skipping.
# Data for TMDb ID 25296.0 already exists. Skipping.
# Data for TMDb ID 40156.0 already exists. Skipping.
# Data for TMDb ID 11450.0 already exists. Skipping.
# Data for TMDb ID 30304.0 already exists. Skipping.
# Data for TMDb ID 10452.0 already exists. Skipping.
# Data for TMDb ID 12106.0 already exists. Skipping.
# Data for TMDb ID 161495.0 already exists. Skipping.
# Data for TMDb ID 3586.0 already exists. Skipping.
# Data for TMDb ID 110.0 already exists. Skipping.
# Data for TMDb ID 108.0 already exists. Skipping.
# Data for TMDb ID 109.0 already exists. Skipping.
# Data for TMDb ID 159185.0 already exists. Skipping.
# Data for TMDb ID 36357.0 already exists. Skipping.
# Data for TMDb ID 92769.0 already exists. Skipping.
# Data for TMDb ID 28033.0 already exists. Skipping.
# Data for TMDb ID 22586.0 already exists. Skipping.
# Data for TMDb ID 14334.0 already exists. Skipping.
# Data for TMDb ID 2636.0 already exists. Skipping.
# Data for TMDb ID 2164.0 already exists. Skipping.
# Data for TMDb ID 11395.0 already exists. Skipping.
# Data for TMDb ID 278.0 already exists. Skipping.
# Data for TMDb ID 9905.0 already exists. Skipping.
# Data for TMDb ID 87078.0 already exists. Skipping.
# Data for TMDb ID 12527.0 already exists. Skipping.
# Data for TMDb ID 20306.0 already exists. Skipping.
# Data for TMDb ID 36614.0 already exists. Skipping.
# Data for TMDb ID 27993.0 already exists. Skipping.
# Data for TMDb ID 31439.0 already exists. Skipping.
# Data for TMDb ID 9067.0 already exists. Skipping.
# Data for TMDb ID 9059.0 already exists. Skipping.
# Data for TMDb ID 193.0 already exists. Skipping.
# Data for TMDb ID 25066.0 already exists. Skipping.
# Data for TMDb ID 46797.0 already exists. Skipping.
# Data for TMDb ID 12122.0 already exists. Skipping.
# Data for TMDb ID 11381.0 already exists. Skipping.
# Data for TMDb ID 32636.0 already exists. Skipping.
# Data for TMDb ID 36141.0 already exists. Skipping.
# Data for TMDb ID 95963.0 already exists. Skipping.
# Data for TMDb ID 1587.0 already exists. Skipping.
# Data for TMDb ID 9271.0 already exists. Skipping.
# Data for TMDb ID 2064.0 already exists. Skipping.
# Data for TMDb ID 19855.0 already exists. Skipping.
# Data for TMDb ID 60855.0 already exists. Skipping.
# Data for TMDb ID 236.0 already exists. Skipping.
# Data for TMDb ID 48287.0 already exists. Skipping.
# Data for TMDb ID 3049.0 already exists. Skipping.
# Data for TMDb ID 2759.0 already exists. Skipping.
# Data for TMDb ID 12635.0 already exists. Skipping.
# Data for TMDb ID 10497.0 already exists. Skipping.
# Data for TMDb ID 11382.0 already exists. Skipping.
# Data for TMDb ID 9331.0 already exists. Skipping.
# Data for TMDb ID 10731.0 already exists. Skipping.
# Data for TMDb ID 10464.0 already exists. Skipping.
# Data for TMDb ID 34152.0 already exists. Skipping.
# Data for TMDb ID 9495.0 already exists. Skipping.
# Data for TMDb ID 29973.0 already exists. Skipping.
# Data for TMDb ID 888.0 already exists. Skipping.
# Data for TMDb ID 13.0 already exists. Skipping.
# Data for TMDb ID 712.0 already exists. Skipping.
# Data for TMDb ID 16295.0 already exists. Skipping.
# Data for TMDb ID 48992.0 already exists. Skipping.
# Data for TMDb ID 10879.0 already exists. Skipping.
# Data for TMDb ID 10660.0 already exists. Skipping.
# Data for TMDb ID 10714.0 already exists. Skipping.
# Data for TMDb ID 41647.0 already exists. Skipping.
# Data for TMDb ID 8587.0 already exists. Skipping.
# Data for TMDb ID 1689.0 already exists. Skipping.
# Data for TMDb ID 11596.0 already exists. Skipping.
# Data for TMDb ID 854.0 already exists. Skipping.
# Data for TMDb ID 9359.0 already exists. Skipping.
# Data for TMDb ID 23333.0 already exists. Skipping.
# Data for TMDb ID 36593.0 already exists. Skipping.
# Data for TMDb ID 12280.0 already exists. Skipping.
# Data for TMDb ID 2788.0 already exists. Skipping.
# Data for TMDb ID 10427.0 already exists. Skipping.
# Data for TMDb ID 11011.0 already exists. Skipping.
# Data for TMDb ID 49803.0 already exists. Skipping.
# Data for TMDb ID 8987.0 already exists. Skipping.
# Data for TMDb ID 1637.0 already exists. Skipping.
# Data for TMDb ID 15128.0 already exists. Skipping.
# Data for TMDb ID 8831.0 already exists. Skipping.
# Data for TMDb ID 36955.0 already exists. Skipping.
# Data for TMDb ID 10449.0 already exists. Skipping.
# Data for TMDb ID 10395.0 already exists. Skipping.
# Data for TMDb ID 12160.0 already exists. Skipping.
# Data for TMDb ID 40480.0 already exists. Skipping.
# Data for TMDb ID 52038.0 already exists. Skipping.
# Data for TMDb ID 29444.0 already exists. Skipping.
# Data for TMDb ID 26352.0 already exists. Skipping.
# Data for TMDb ID 39953.0 already exists. Skipping.
# Data for TMDb ID 41580.0 already exists. Skipping.
# Data for TMDb ID 315.0 already exists. Skipping.
# Data for TMDb ID 22067.0 already exists. Skipping.
# Data for TMDb ID 18242.0 already exists. Skipping.
# Data for TMDb ID 11667.0 already exists. Skipping.
# Data for TMDb ID 32502.0 already exists. Skipping.
# Data for TMDb ID 267188.0 already exists. Skipping.
# Data for TMDb ID 28732.0 already exists. Skipping.
# Data for TMDb ID 75555.0 already exists. Skipping.
# Data for TMDb ID 42981.0 already exists. Skipping.
# Data for TMDb ID 278939.0 already exists. Skipping.
# Data for TMDb ID 291731.0 already exists. Skipping.
# Data for TMDb ID 226229.0 already exists. Skipping.
# Data for TMDb ID 203119.0 already exists. Skipping.
# Data for TMDb ID 172923.0 already exists. Skipping.
# Data for TMDb ID 316098.0 already exists. Skipping.
# Data for TMDb ID 8011.0 already exists. Skipping.
# Data for TMDb ID 171857.0 already exists. Skipping.
# Data for TMDb ID 2654.0 already exists. Skipping.
# Data for TMDb ID 18069.0 already exists. Skipping.
# Data for TMDb ID 19092.0 already exists. Skipping.
# Data for TMDb ID 2758.0 already exists. Skipping.
# Data for TMDb ID 38129.0 already exists. Skipping.
# Data for TMDb ID 10436.0 already exists. Skipping.
# Data for TMDb ID 13595.0 already exists. Skipping.
# Data for TMDb ID 46094.0 already exists. Skipping.
# Data for TMDb ID 9409.0 already exists. Skipping.
# Data for TMDb ID 11853.0 already exists. Skipping.
# Data for TMDb ID 16771.0 already exists. Skipping.
# Data for TMDb ID 46924.0 already exists. Skipping.
# Data for TMDb ID 11041.0 already exists. Skipping.
# Data for TMDb ID 306.0 already exists. Skipping.
# Data for TMDb ID 14522.0 already exists. Skipping.
# Data for TMDb ID 26203.0 already exists. Skipping.
# Data for TMDb ID 178.0 already exists. Skipping.
# Data for TMDb ID 19819.0 already exists. Skipping.
# Data for TMDb ID 57834.0 already exists. Skipping.
# Data for TMDb ID 4722.0 already exists. Skipping.
# Data for TMDb ID 18215.0 already exists. Skipping.
# Data for TMDb ID 1607.0 already exists. Skipping.
# Data for TMDb ID 26391.0 already exists. Skipping.
# Data for TMDb ID 117553.0 already exists. Skipping.
# Data for TMDb ID 6075.0 already exists. Skipping.
# Data for TMDb ID 11310.0 already exists. Skipping.
# Data for TMDb ID 18658.0 already exists. Skipping.
# Data for TMDb ID 9350.0 already exists. Skipping.
# Data for TMDb ID 9612.0 already exists. Skipping.
# Data for TMDb ID 2124.0 already exists. Skipping.
# Data for TMDb ID 26261.0 already exists. Skipping.
# Data for TMDb ID 19176.0 already exists. Skipping.
# Data for TMDb ID 49299.0 already exists. Skipping.
# Data for TMDb ID 11566.0 already exists. Skipping.
# Data for TMDb ID 9571.0 already exists. Skipping.
# Data for TMDb ID 9739.0 already exists. Skipping.
# Data for TMDb ID 24257.0 already exists. Skipping.
# Data for TMDb ID 34444.0 already exists. Skipping.
# Data for TMDb ID 26141.0 already exists. Skipping.
# Data for TMDb ID 10997.0 already exists. Skipping.
# Data for TMDb ID 50463.0 already exists. Skipping.
# Data for TMDb ID 10443.0 already exists. Skipping.
# Data for TMDb ID 20239.0 already exists. Skipping.
# Data for TMDb ID 16297.0 already exists. Skipping.
# Data for TMDb ID 18551.0 already exists. Skipping.
# Data for TMDb ID 25440.0 already exists. Skipping.
# Data for TMDb ID 9024.0 already exists. Skipping.
# Data for TMDb ID 37233.0 already exists. Skipping.
# Data for TMDb ID 1634.0 already exists. Skipping.
# Data for TMDb ID 13815.0 already exists. Skipping.
# Data for TMDb ID 5503.0 already exists. Skipping.
# Data for TMDb ID 35588.0 already exists. Skipping.
# Data for TMDb ID 2087.0 already exists. Skipping.
# Data for TMDb ID 41579.0 already exists. Skipping.
# Data for TMDb ID 18620.0 already exists. Skipping.
# Data for TMDb ID 41006.0 already exists. Skipping.
# Data for TMDb ID 4916.0 already exists. Skipping.
# Data for TMDb ID 2019.0 already exists. Skipping.
# Data for TMDb ID 31642.0 already exists. Skipping.
# Data for TMDb ID 9255.0 already exists. Skipping.
# Data for TMDb ID 26271.0 already exists. Skipping.
# Data for TMDb ID 10612.0 already exists. Skipping.
# Data for TMDb ID 2259.0 already exists. Skipping.
# Data for TMDb ID 16097.0 already exists. Skipping.
# Data for TMDb ID 11934.0 already exists. Skipping.
# Data for TMDb ID 106143.0 already exists. Skipping.
# Data for TMDb ID 12475.0 already exists. Skipping.
# Data for TMDb ID 9386.0 already exists. Skipping.
# Data for TMDb ID 7984.0 already exists. Skipping.
# Data for TMDb ID 59930.0 already exists. Skipping.
# Data for TMDb ID 15765.0 already exists. Skipping.
# Data for TMDb ID 31643.0 already exists. Skipping.
# Data for TMDb ID 6.0 already exists. Skipping.
# Data for TMDb ID 329.0 already exists. Skipping.
# Data for TMDb ID 10909.0 already exists. Skipping.
# Data for TMDb ID 507.0 already exists. Skipping.
# Data for TMDb ID 34024.0 already exists. Skipping.
# Data for TMDb ID 29918.0 already exists. Skipping.
# Data for TMDb ID 9593.0 already exists. Skipping.
# Data for TMDb ID 42580.0 already exists. Skipping.
# Data for TMDb ID 22317.0 already exists. Skipping.
# Data for TMDb ID 1413.0 already exists. Skipping.
# Data for TMDb ID 12121.0 already exists. Skipping.
# Data for TMDb ID 2246.0 already exists. Skipping.
# Data for TMDb ID 10502.0 already exists. Skipping.
# Data for TMDb ID 10440.0 already exists. Skipping.
# Data for TMDb ID 9516.0 already exists. Skipping.
# Data for TMDb ID 2320.0 already exists. Skipping.
# Data for TMDb ID 5879.0 already exists. Skipping.
# Data for TMDb ID 83718.0 already exists. Skipping.
# Data for TMDb ID 11971.0 already exists. Skipping.
# Data for TMDb ID 2625.0 already exists. Skipping.
# Data for TMDb ID 31911.0 already exists. Skipping.
# Data for TMDb ID 788.0 already exists. Skipping.
# Data for TMDb ID 21450.0 already exists. Skipping.
# Data for TMDb ID 11231.0 already exists. Skipping.
# Data for TMDb ID 41588.0 already exists. Skipping.
# Data for TMDb ID 10447.0 already exists. Skipping.
# Data for TMDb ID 31586.0 already exists. Skipping.
# Data for TMDb ID 9300.0 already exists. Skipping.
# Data for TMDb ID 9559.0 already exists. Skipping.
# Data for TMDb ID 9800.0 already exists. Skipping.
# Data for TMDb ID 713.0 already exists. Skipping.
# Data for TMDb ID 8291.0 already exists. Skipping.
# Data for TMDb ID 18133.0 already exists. Skipping.
# Data for TMDb ID 25557.0 already exists. Skipping.
# Data for TMDb ID 22588.0 already exists. Skipping.
# Data for TMDb ID 10872.0 already exists. Skipping.
# Data for TMDb ID 1245.0 already exists. Skipping.
# Data for TMDb ID 11858.0 already exists. Skipping.
# Data for TMDb ID 7007.0 already exists. Skipping.
# Data for TMDb ID 10467.0 already exists. Skipping.
# Data for TMDb ID 5550.0 already exists. Skipping.
# Data for TMDb ID 8005.0 already exists. Skipping.
# Data for TMDb ID 2088.0 already exists. Skipping.
# Data for TMDb ID 10412.0 already exists. Skipping.
# Data for TMDb ID 47889.0 already exists. Skipping.
# Data for TMDb ID 14534.0 already exists. Skipping.
# Data for TMDb ID 56583.0 already exists. Skipping.
# Data for TMDb ID 41878.0 already exists. Skipping.
# Data for TMDb ID 424.0 already exists. Skipping.
# Data for TMDb ID 35233.0 already exists. Skipping.
# Data for TMDb ID 14291.0 already exists. Skipping.
# Data for TMDb ID 103413.0 already exists. Skipping.
# Data for TMDb ID 11236.0 already exists. Skipping.
# Data for TMDb ID 11592.0 already exists. Skipping.
# Data for TMDb ID 8850.0 already exists. Skipping.
# Data for TMDb ID 10445.0 already exists. Skipping.
# Data for TMDb ID 695.0 already exists. Skipping.
# Data for TMDb ID 43535.0 already exists. Skipping.
# Data for TMDb ID 12519.0 already exists. Skipping.
# Data for TMDb ID 23210.0 already exists. Skipping.
# Data for TMDb ID 858.0 already exists. Skipping.
# Data for TMDb ID 867.0 already exists. Skipping.
# Data for TMDb ID 78.0 already exists. Skipping.
# Data for TMDb ID 13203.0 already exists. Skipping.
# Data for TMDb ID 10442.0 already exists. Skipping.
# Data for TMDb ID 11074.0 already exists. Skipping.
# Data for TMDb ID 9607.0 already exists. Skipping.
# Data for TMDb ID 17585.0 already exists. Skipping.
# Data for TMDb ID 9057.0 already exists. Skipping.
# Data for TMDb ID 20967.0 already exists. Skipping.
# Data for TMDb ID 10635.0 already exists. Skipping.
# Data for TMDb ID 9479.0 already exists. Skipping.
# Data for TMDb ID 10057.0 already exists. Skipping.
# Data for TMDb ID 11969.0 already exists. Skipping.
# Data for TMDb ID 41590.0 already exists. Skipping.
# Data for TMDb ID 319.0 already exists. Skipping.
# Data for TMDb ID 26408.0 already exists. Skipping.
# Data for TMDb ID 15139.0 already exists. Skipping.
# Data for TMDb ID 161158.0 already exists. Skipping.
# Data for TMDb ID 218473.0 already exists. Skipping.
# Data for TMDb ID 85247.0 already exists. Skipping.
# Data for TMDb ID 11446.0 already exists. Skipping.
# Data for TMDb ID 51980.0 already exists. Skipping.
# Data for TMDb ID 24405.0 already exists. Skipping.
# Data for TMDb ID 11655.0 already exists. Skipping.
# Data for TMDb ID 11800.0 already exists. Skipping.
# Data for TMDb ID 8223.0 already exists. Skipping.
# Data for TMDb ID 14587.0 already exists. Skipping.
# Data for TMDb ID 31504.0 already exists. Skipping.
# Data for TMDb ID 41653.0 already exists. Skipping.
# Data for TMDb ID 53185.0 already exists. Skipping.
# Data for TMDb ID 95743.0 already exists. Skipping.
# Data for TMDb ID 23637.0 already exists. Skipping.
# Data for TMDb ID 17600.0 already exists. Skipping.
# Data for TMDb ID 10897.0 already exists. Skipping.
# Data for TMDb ID 349394.0 already exists. Skipping.
# Data for TMDb ID 21352.0 already exists. Skipping.
# Data for TMDb ID 68806.0 already exists. Skipping.
# Data for TMDb ID 37345.0 already exists. Skipping.
# Data for TMDb ID 32562.0 already exists. Skipping.
# Data for TMDb ID 47507.0 already exists. Skipping.
# Data for TMDb ID 25403.0 already exists. Skipping.
# Data for TMDb ID 124304.0 already exists. Skipping.
# Data for TMDb ID 9066.0 already exists. Skipping.
# Data for TMDb ID 771.0 already exists. Skipping.
# Data for TMDb ID 251.0 already exists. Skipping.
# Data for TMDb ID 812.0 already exists. Skipping.
# Data for TMDb ID 280.0 already exists. Skipping.
# Data for TMDb ID 581.0 already exists. Skipping.
# Data for TMDb ID 80350.0 already exists. Skipping.
# Data for TMDb ID 268.0 already exists. Skipping.
# Data for TMDb ID 274.0 already exists. Skipping.
# Data for TMDb ID 408.0 already exists. Skipping.
# Data for TMDb ID 10020.0 already exists. Skipping.
# Data for TMDb ID 10895.0 already exists. Skipping.
# Data for TMDb ID 114.0 already exists. Skipping.
# Data for TMDb ID 41043.0 already exists. Skipping.
# Data for TMDb ID 576.0 already exists. Skipping.
# Data for TMDb ID 15477.0 already exists. Skipping.
# Data for TMDb ID 59146.0 already exists. Skipping.
# Data for TMDb ID 124472.0 already exists. Skipping.
# Data for TMDb ID 30528.0 already exists. Skipping.
# Error fetching data for TMDb ID 538286: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/538286?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Data for TMDb ID 7300.0 already exists. Skipping.
# Data for TMDb ID 10824.0 already exists. Skipping.
# Data for TMDb ID 261246.0 already exists. Skipping.
# Data for TMDb ID 275.0 already exists. Skipping.
# Data for TMDb ID 25059.0 already exists. Skipping.
# Data for TMDb ID 11827.0 already exists. Skipping.
# Data for TMDb ID 8766.0 already exists. Skipping.
# Data for TMDb ID 23570.0 already exists. Skipping.
# Data for TMDb ID 47333.0 already exists. Skipping.
# Data for TMDb ID 54850.0 already exists. Skipping.
# Data for TMDb ID 51242.0 already exists. Skipping.
# Data for TMDb ID 10112.0 already exists. Skipping.
# Data for TMDb ID 4307.0 already exists. Skipping.
# Data for TMDb ID 46029.0 already exists. Skipping.
# Data for TMDb ID 32308.0 already exists. Skipping.
# Data for TMDb ID 88893.0 already exists. Skipping.
# Data for TMDb ID 52873.0 already exists. Skipping.
# Data for TMDb ID 123505.0 already exists. Skipping.
# Data for TMDb ID 44281.0 already exists. Skipping.
# Data for TMDb ID 28121.0 already exists. Skipping.
# Data for TMDb ID 12520.0 already exists. Skipping.
# Data for TMDb ID 1592.0 already exists. Skipping.
# Data for TMDb ID 166901.0 already exists. Skipping.
# Data for TMDb ID 36447.0 already exists. Skipping.
# Data for TMDb ID 19042.0 already exists. Skipping.
# Data for TMDb ID 38884.0 already exists. Skipping.
# Data for TMDb ID 47449.0 already exists. Skipping.
# Data for TMDb ID 36259.0 already exists. Skipping.
# Data for TMDb ID 41852.0 already exists. Skipping.
# Data for TMDb ID 40926.0 already exists. Skipping.
# Data for TMDb ID 9099.0 already exists. Skipping.
# Data for TMDb ID 2021.0 already exists. Skipping.
# Data for TMDb ID 61752.0 already exists. Skipping.
# Data for TMDb ID 10988.0 already exists. Skipping.
# Data for TMDb ID 11479.0 already exists. Skipping.
# Data for TMDb ID 398959.0 already exists. Skipping.
# Data for TMDb ID 287305.0 already exists. Skipping.
# Data for TMDb ID 339428.0 already exists. Skipping.
# Data for TMDb ID 12652.0 already exists. Skipping.
# Data for TMDb ID 10684.0 already exists. Skipping.
# Data for TMDb ID 954.0 already exists. Skipping.
# Data for TMDb ID 68445.0 already exists. Skipping.
# Data for TMDb ID 18989.0 already exists. Skipping.
# Data for TMDb ID 10801.0 already exists. Skipping.
# Data for TMDb ID 54285.0 already exists. Skipping.
# Data for TMDb ID 8840.0 already exists. Skipping.
# Data for TMDb ID 278978.0 already exists. Skipping.
# Data for TMDb ID 124625.0 already exists. Skipping.
# Data for TMDb ID 11107.0 already exists. Skipping.
# Data for TMDb ID 16417.0 already exists. Skipping.
# Data for TMDb ID 70934.0 already exists. Skipping.
# Data for TMDb ID 10363.0 already exists. Skipping.
# Data for TMDb ID 161070.0 already exists. Skipping.
# Data for TMDb ID 10539.0 already exists. Skipping.
# Data for TMDb ID 10543.0 already exists. Skipping.
# Data for TMDb ID 18414.0 already exists. Skipping.
# Data for TMDb ID 47502.0 already exists. Skipping.
# Data for TMDb ID 11902.0 already exists. Skipping.
# Data for TMDb ID 27098.0 already exists. Skipping.
# Data for TMDb ID 25087.0 already exists. Skipping.
# Data for TMDb ID 5801.0 already exists. Skipping.
# Data for TMDb ID 896.0 already exists. Skipping.
# Data for TMDb ID 3065.0 already exists. Skipping.
# Data for TMDb ID 318177.0 already exists. Skipping.
# Data for TMDb ID 2300.0 already exists. Skipping.
# Data for TMDb ID 8069.0 already exists. Skipping.
# Data for TMDb ID 288173.0 already exists. Skipping.
# Data for TMDb ID 187851.0 already exists. Skipping.
# Data for TMDb ID 27768.0 already exists. Skipping.
# Data for TMDb ID 221917.0 already exists. Skipping.
# Data for TMDb ID 8072.0 already exists. Skipping.
# Data for TMDb ID 35797.0 already exists. Skipping.
# Data for TMDb ID 88030.0 already exists. Skipping.
# Data for TMDb ID 185191.0 already exists. Skipping.
# Data for TMDb ID 83857.0 already exists. Skipping.
# Data for TMDb ID 33245.0 already exists. Skipping.
# Data for TMDb ID 124460.0 already exists. Skipping.
# Data for TMDb ID 27281.0 already exists. Skipping.
# Data for TMDb ID 105045.0 already exists. Skipping.
# Data for TMDb ID 40001.0 already exists. Skipping.
# Data for TMDb ID 29621.0 already exists. Skipping.
# Data for TMDb ID 117730.0 already exists. Skipping.
# Data for TMDb ID 20762.0 already exists. Skipping.
# Data for TMDb ID 37144.0 already exists. Skipping.
# Data for TMDb ID 48260.0 already exists. Skipping.
# Data for TMDb ID 12656.0 already exists. Skipping.
# Data for TMDb ID 38867.0 already exists. Skipping.
# Data for TMDb ID 277270.0 already exists. Skipping.
# Data for TMDb ID 25969.0 already exists. Skipping.
# Data for TMDb ID 44103.0 already exists. Skipping.
# Data for TMDb ID 753.0 already exists. Skipping.
# Data for TMDb ID 43634.0 already exists. Skipping.
# Data for TMDb ID 9103.0 already exists. Skipping.
# Data for TMDb ID 90214.0 already exists. Skipping.
# Data for TMDb ID 29649.0 already exists. Skipping.
# Data for TMDb ID 10990.0 already exists. Skipping.
# Data for TMDb ID 8866.0 already exists. Skipping.
# Data for TMDb ID 12233.0 already exists. Skipping.
# Data for TMDb ID 23449.0 already exists. Skipping.
# Data for TMDb ID 36355.0 already exists. Skipping.
# Data for TMDb ID 37667.0 already exists. Skipping.
# Data for TMDb ID 90148.0 already exists. Skipping.
# Data for TMDb ID 922.0 already exists. Skipping.
# Data for TMDb ID 11876.0 already exists. Skipping.
# Data for TMDb ID 52633.0 already exists. Skipping.
# Data for TMDb ID 62364.0 already exists. Skipping.
# Data for TMDb ID 11687.0 already exists. Skipping.
# Data for TMDb ID 9304.0 already exists. Skipping.
# Data for TMDb ID 503475.0 already exists. Skipping.
# Data for TMDb ID 73183.0 already exists. Skipping.
# Data for TMDb ID 123067.0 already exists. Skipping.
# Data for TMDb ID 9100.0 already exists. Skipping.
# Data for TMDb ID 20759.0 already exists. Skipping.
# Data for TMDb ID 46063.0 already exists. Skipping.
# Data for TMDb ID 365371.0 already exists. Skipping.
# Data for TMDb ID 32513.0 already exists. Skipping.
# Data for TMDb ID 40651.0 already exists. Skipping.
# Data for TMDb ID 36915.0 already exists. Skipping.
# Data for TMDb ID 40507.0 already exists. Skipping.
# Data for TMDb ID 9802.0 already exists. Skipping.
# Data for TMDb ID 25697.0 already exists. Skipping.
# Data for TMDb ID 21588.0 already exists. Skipping.
# Data for TMDb ID 664.0 already exists. Skipping.
# Data for TMDb ID 11867.0 already exists. Skipping.
# Data for TMDb ID 47119.0 already exists. Skipping.
# Data for TMDb ID 314352.0 already exists. Skipping.
# Data for TMDb ID 9323.0 already exists. Skipping.
# Data for TMDb ID 10280.0 already exists. Skipping.
# Data for TMDb ID 10535.0 already exists. Skipping.
# Data for TMDb ID 124613.0 already exists. Skipping.
# Data for TMDb ID 532.0 already exists. Skipping.
# Data for TMDb ID 26744.0 already exists. Skipping.
# Data for TMDb ID 16299.0 already exists. Skipping.
# Data for TMDb ID 10547.0 already exists. Skipping.
# Data for TMDb ID 245268.0 already exists. Skipping.
# Data for TMDb ID 935.0 already exists. Skipping.
# Data for TMDb ID 55613.0 already exists. Skipping.
# Data for TMDb ID 215107.0 already exists. Skipping.
# Data for TMDb ID 41007.0 already exists. Skipping.
# Data for TMDb ID 35645.0 already exists. Skipping.
# Data for TMDb ID 110465.0 already exists. Skipping.
# Data for TMDb ID 255546.0 already exists. Skipping.
# Data for TMDb ID 40751.0 already exists. Skipping.
# Data for TMDb ID 275096.0 already exists. Skipping.
# Data for TMDb ID 85778.0 already exists. Skipping.
# Data for TMDb ID 11101.0 already exists. Skipping.
# Data for TMDb ID 9826.0 already exists. Skipping.
# Data for TMDb ID 9879.0 already exists. Skipping.
# Data for TMDb ID 63564.0 already exists. Skipping.
# Data for TMDb ID 22621.0 already exists. Skipping.
# Data for TMDb ID 7095.0 already exists. Skipping.
# Data for TMDb ID 26890.0 already exists. Skipping.
# Data for TMDb ID 46732.0 already exists. Skipping.
# Data for TMDb ID 124633.0 already exists. Skipping.
# Data for TMDb ID 581579.0 already exists. Skipping.
# Data for TMDb ID 202425.0 already exists. Skipping.
# Data for TMDb ID 196940.0 already exists. Skipping.
# Data for TMDb ID 77771.0 already exists. Skipping.
# Data for TMDb ID 181083.0 already exists. Skipping.
# Data for TMDb ID 41225.0 already exists. Skipping.
# Data for TMDb ID 188589.0 already exists. Skipping.
# Data for TMDb ID 87190.0 already exists. Skipping.
# Data for TMDb ID 627.0 already exists. Skipping.
# Data for TMDb ID 32872.0 already exists. Skipping.
# Data for TMDb ID 602.0 already exists. Skipping.
# Data for TMDb ID 14553.0 already exists. Skipping.
# Data for TMDb ID 9566.0 already exists. Skipping.
# Data for TMDb ID 10545.0 already exists. Skipping.
# Data for TMDb ID 9894.0 already exists. Skipping.
# Data for TMDb ID 11543.0 already exists. Skipping.
# Data for TMDb ID 9268.0 already exists. Skipping.
# Data for TMDb ID 52059.0 already exists. Skipping.
# Data for TMDb ID 9327.0 already exists. Skipping.
# Data for TMDb ID 123763.0 already exists. Skipping.
# Data for TMDb ID 81949.0 already exists. Skipping.
# Data for TMDb ID 42005.0 already exists. Skipping.
# Data for TMDb ID 124306.0 already exists. Skipping.
# Data for TMDb ID 183955.0 already exists. Skipping.
# Data for TMDb ID 44535.0 already exists. Skipping.
# Data for TMDb ID 44495.0 already exists. Skipping.
# Data for TMDb ID 78285.0 already exists. Skipping.
# Data for TMDb ID 11228.0 already exists. Skipping.
# Data for TMDb ID 10779.0 already exists. Skipping.
# Data for TMDb ID 26748.0 already exists. Skipping.
# Data for TMDb ID 38223.0 already exists. Skipping.
# Data for TMDb ID 9294.0 already exists. Skipping.
# Data for TMDb ID 49963.0 already exists. Skipping.
# Data for TMDb ID 11363.0 already exists. Skipping.
# Data for TMDb ID 1645.0 already exists. Skipping.
# Data for TMDb ID 31546.0 already exists. Skipping.
# Data for TMDb ID 77056.0 already exists. Skipping.
# Data for TMDb ID 36344.0 already exists. Skipping.
# Data for TMDb ID 18550.0 already exists. Skipping.
# Data for TMDb ID 11511.0 already exists. Skipping.
# Data for TMDb ID 172198.0 already exists. Skipping.
# Data for TMDb ID 34170.0 already exists. Skipping.
# Data for TMDb ID 281085.0 already exists. Skipping.
# Data for TMDb ID 109478.0 already exists. Skipping.
# Data for TMDb ID 124645.0 already exists. Skipping.
# Data for TMDb ID 12606.0 already exists. Skipping.
# Data for TMDb ID 69895.0 already exists. Skipping.
# Data for TMDb ID 35206.0 already exists. Skipping.
# Data for TMDb ID 525936.0 already exists. Skipping.
# Data for TMDb ID 151489.0 already exists. Skipping.
# Data for TMDb ID 4837.0 already exists. Skipping.
# Data for TMDb ID 12632.0 already exists. Skipping.
# Data for TMDb ID 9098.0 already exists. Skipping.
# Data for TMDb ID 282919.0 already exists. Skipping.
# Data for TMDb ID 124614.0 already exists. Skipping.
# Data for TMDb ID 18975.0 already exists. Skipping.
# Data for TMDb ID 11962.0 already exists. Skipping.
# Data for TMDb ID 2925.0 already exists. Skipping.
# Data for TMDb ID 28628.0 already exists. Skipping.
# Data for TMDb ID 3595.0 already exists. Skipping.
# Data for TMDb ID 9308.0 already exists. Skipping.
# Data for TMDb ID 92381.0 already exists. Skipping.
# Data for TMDb ID 18555.0 already exists. Skipping.
# Data for TMDb ID 12123.0 already exists. Skipping.
# Data for TMDb ID 10830.0 already exists. Skipping.
# Data for TMDb ID 3573.0 already exists. Skipping.
# Data for TMDb ID 10546.0 already exists. Skipping.
# Data for TMDb ID 18862.0 already exists. Skipping.
# Data for TMDb ID 31417.0 already exists. Skipping.
# Data for TMDb ID 9431.0 already exists. Skipping.
# Data for TMDb ID 124619.0 already exists. Skipping.
# Data for TMDb ID 297645.0 already exists. Skipping.
# Data for TMDb ID 48144.0 already exists. Skipping.
# Data for TMDb ID 46986.0 already exists. Skipping.
# Data for TMDb ID 144982.0 already exists. Skipping.
# Data for TMDb ID 47907.0 already exists. Skipping.
# Data for TMDb ID 10061.0 already exists. Skipping.
# Data for TMDb ID 36266.0 already exists. Skipping.
# Data for TMDb ID 549.0 already exists. Skipping.
# Data for TMDb ID 10478.0 already exists. Skipping.
# Data for TMDb ID 66634.0 already exists. Skipping.
# Data for TMDb ID 116690.0 already exists. Skipping.
# Data for TMDb ID 213917.0 already exists. Skipping.
# Data for TMDb ID 145925.0 already exists. Skipping.
# Data for TMDb ID 100914.0 already exists. Skipping.
# Data for TMDb ID 238.0 already exists. Skipping.
# Data for TMDb ID 484245.0 already exists. Skipping.
# Data for TMDb ID 159.0 already exists. Skipping.
# Data for TMDb ID 11134.0 already exists. Skipping.
# Data for TMDb ID 88224.0 already exists. Skipping.
# Data for TMDb ID 132641.0 already exists. Skipping.
# Data for TMDb ID 42758.0 already exists. Skipping.
# Data for TMDb ID 9303.0 already exists. Skipping.
# Data for TMDb ID 23945.0 already exists. Skipping.
# Data for TMDb ID 37820.0 already exists. Skipping.
# Data for TMDb ID 22479.0 already exists. Skipping.
# Data for TMDb ID 9054.0 already exists. Skipping.
# Data for TMDb ID 241058.0 already exists. Skipping.
# Data for TMDb ID 11985.0 already exists. Skipping.
# Data for TMDb ID 10232.0 already exists. Skipping.
# Data for TMDb ID 59569.0 already exists. Skipping.
# Data for TMDb ID 410921.0 already exists. Skipping.
# Data for TMDb ID 38955.0 already exists. Skipping.
# Data for TMDb ID 110513.0 already exists. Skipping.
# Data for TMDb ID 114089.0 already exists. Skipping.
# Data for TMDb ID 11015.0 already exists. Skipping.
# Data for TMDb ID 9306.0 already exists. Skipping.
# Data for TMDb ID 12559.0 already exists. Skipping.
# Data for TMDb ID 58770.0 already exists. Skipping.
# Data for TMDb ID 124851.0 already exists. Skipping.
# Data for TMDb ID 3587.0 already exists. Skipping.
# Data for TMDb ID 10723.0 already exists. Skipping.
# Data for TMDb ID 56077.0 already exists. Skipping.
# Data for TMDb ID 101230.0 already exists. Skipping.
# Data for TMDb ID 253632.0 already exists. Skipping.
# Data for TMDb ID 10987.0 already exists. Skipping.
# Data for TMDb ID 44705.0 already exists. Skipping.
# Data for TMDb ID 20318.0 already exists. Skipping.
# Data for TMDb ID 43596.0 already exists. Skipping.
# Data for TMDb ID 79782.0 already exists. Skipping.
# Data for TMDb ID 26933.0 already exists. Skipping.
# Data for TMDb ID 27854.0 already exists. Skipping.
# Data for TMDb ID 981.0 already exists. Skipping.
# Data for TMDb ID 872.0 already exists. Skipping.
# Data for TMDb ID 2769.0 already exists. Skipping.
# Data for TMDb ID 13320.0 already exists. Skipping.
# Data for TMDb ID 164.0 already exists. Skipping.
# Data for TMDb ID 426.0 already exists. Skipping.
# Data for TMDb ID 567.0 already exists. Skipping.
# Data for TMDb ID 3078.0 already exists. Skipping.
# Data for TMDb ID 13528.0 already exists. Skipping.
# Data for TMDb ID 28288.0 already exists. Skipping.
# Data for TMDb ID 213.0 already exists. Skipping.
# Data for TMDb ID 284.0 already exists. Skipping.
# Data for TMDb ID 239.0 already exists. Skipping.
# Data for TMDb ID 4808.0 already exists. Skipping.
# Data for TMDb ID 289.0 already exists. Skipping.
# Data for TMDb ID 963.0 already exists. Skipping.
# Data for TMDb ID 11113.0 already exists. Skipping.
# Data for TMDb ID 6620.0 already exists. Skipping.
# Data for TMDb ID 804.0 already exists. Skipping.
# Data for TMDb ID 26531.0 already exists. Skipping.
# Data for TMDb ID 909.0 already exists. Skipping.
# Data for TMDb ID 630.0 already exists. Skipping.
# Data for TMDb ID 770.0 already exists. Skipping.
# Data for TMDb ID 31044.0 already exists. Skipping.
# Data for TMDb ID 599.0 already exists. Skipping.
# Data for TMDb ID 15.0 already exists. Skipping.
# Data for TMDb ID 62.0 already exists. Skipping.
# Data for TMDb ID 121357.0 already exists. Skipping.
# Data for TMDb ID 705.0 already exists. Skipping.
# Data for TMDb ID 22490.0 already exists. Skipping.
# Data for TMDb ID 223.0 already exists. Skipping.
# Data for TMDb ID 25670.0 already exists. Skipping.
# Data for TMDb ID 303.0 already exists. Skipping.
# Data for TMDb ID 4174.0 already exists. Skipping.
# Data for TMDb ID 8356.0 already exists. Skipping.
# Data for TMDb ID 381.0 already exists. Skipping.
# Data for TMDb ID 20758.0 already exists. Skipping.
# Data for TMDb ID 29376.0 already exists. Skipping.
# Data for TMDb ID 1859.0 already exists. Skipping.
# Data for TMDb ID 18299.0 already exists. Skipping.
# Data for TMDb ID 17281.0 already exists. Skipping.
# Data for TMDb ID 64382.0 already exists. Skipping.
# Data for TMDb ID 10907.0 already exists. Skipping.
# Data for TMDb ID 32093.0 already exists. Skipping.
# Data for TMDb ID 1939.0 already exists. Skipping.
# Data for TMDb ID 22292.0 already exists. Skipping.
# Data for TMDb ID 3598.0 already exists. Skipping.
# Data for TMDb ID 3080.0 already exists. Skipping.
# Data for TMDb ID 198.0 already exists. Skipping.
# Data for TMDb ID 13562.0 already exists. Skipping.
# Data for TMDb ID 1712.0 already exists. Skipping.
# Data for TMDb ID 220.0 already exists. Skipping.
# Data for TMDb ID 3529.0 already exists. Skipping.
# Data for TMDb ID 3085.0 already exists. Skipping.
# Data for TMDb ID 2897.0 already exists. Skipping.
# Data for TMDb ID 1585.0 already exists. Skipping.
# Data for TMDb ID 3083.0 already exists. Skipping.
# Data for TMDb ID 900.0 already exists. Skipping.
# Data for TMDb ID 43795.0 already exists. Skipping.
# Data for TMDb ID 85638.0 already exists. Skipping.
# Data for TMDb ID 50001.0 already exists. Skipping.
# Data for TMDb ID 43905.0 already exists. Skipping.
# Data for TMDb ID 22688.0 already exists. Skipping.
# Data for TMDb ID 23114.0 already exists. Skipping.
# Data for TMDb ID 26378.0 already exists. Skipping.
# Data for TMDb ID 40206.0 already exists. Skipping.
# Data for TMDb ID 22356.0 already exists. Skipping.
# Data for TMDb ID 260.0 already exists. Skipping.
# Data for TMDb ID 43488.0 already exists. Skipping.
# Data for TMDb ID 22613.0 already exists. Skipping.
# Data for TMDb ID 10331.0 already exists. Skipping.
# Data for TMDb ID 488.0 already exists. Skipping.
# ...
# Error fetching data for TMDb ID 487050: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/487050?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 730788: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/730788?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 299047: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/299047?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 842496: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/842496?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Data for TMDb ID 116440.0 already exists. Skipping.
# Error fetching data for TMDb ID 845074: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/845074?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 470560: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/470560?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 833224: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/833224?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 833915: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/833915?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 839298: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/839298?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 780367: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/780367?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 780371: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/780371?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 635838: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/635838?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 112679: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/112679?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 452765: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/452765?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 313744: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/313744?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 531522: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/531522?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 307842: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/307842?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Data for TMDb ID 521777.0 already exists. Skipping.
# Data for TMDb ID 317190.0 already exists. Skipping.
# Data for TMDb ID 642732.0 already exists. Skipping.
# Error fetching data for TMDb ID 497256: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/497256?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Data for TMDb ID 58451.0 already exists. Skipping.
# Error fetching data for TMDb ID 853673: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/853673?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 815144: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/815144?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 686667: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/686667?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 730639: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/730639?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 858174: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/858174?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 851112: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/851112?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Data for TMDb ID 335209.0 already exists. Skipping.
# Error fetching data for TMDb ID 798481: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/798481?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 201670: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/201670?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 823837: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/823837?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 496125: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/496125?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 748121: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/748121?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 831360: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/831360?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 553296: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/553296?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 875337: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/875337?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 875336: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/875336?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Data for TMDb ID 264068.0 already exists. Skipping.
# Error fetching data for TMDb ID 917505: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/917505?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 362914: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/362914?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 257104: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/257104?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 602524: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/602524?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 274896: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/274896?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 934126: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/934126?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 744247: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/744247?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 936456: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/936456?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 934109: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/934109?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 934096: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/934096?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 471694: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/471694?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 949506: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/949506?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 950025: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/950025?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 957115: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/957115?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 732922: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/732922?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Data for TMDb ID 133919.0 already exists. Skipping.
# Error fetching data for TMDb ID 958198: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/958198?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 949778: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/949778?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 972022: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/972022?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 970060: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/970060?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 567712: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/567712?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 497867: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/497867?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 704352: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/704352?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 763834: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/763834?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Data for TMDb ID 159898.0 already exists. Skipping.
# Error fetching data for TMDb ID 982987: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/982987?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 381789: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/381789?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 983443: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/983443?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1005682: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1005682?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1008469: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1008469?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 461581: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/461581?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 969086: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/969086?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 666716: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/666716?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 881931: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/881931?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1027888: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1027888?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 995460: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/995460?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 182942: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/182942?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1008573: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1008573?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 354402: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/354402?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 963590: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/963590?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 958637: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/958637?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1026872: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1026872?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1077814: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1077814?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1054831: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1054831?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1058029: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1058029?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1107516: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1107516?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1105518: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1105518?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1130353: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1130353?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1061605: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1061605?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1102551: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1102551?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 277090: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/277090?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1114081: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1114081?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1172627: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1172627?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1172634: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1172634?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1173102: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1173102?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 945397: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/945397?api_key=04826aaa5a7349d28828c140963b6483&language=en-US
# Error fetching data for TMDb ID 1136321: 404 Client Error: Not Found for url: https://api.themoviedb.org/3/movie/1136321?api_key=04826aaa5a7349d28828c140963b6483&language=en-US

# %% [markdown]
# Parse the saved data and enrich the content features:

# %%
import os
import json
import pandas as pd
import csv

# Step 1: Read links.csv
links_df = pd.read_csv('data/ml-32m/links.csv')

# Directory containing the enriched JSON files
enriched_dir = 'data/enriched'

# Prepare a list to hold enriched movie data
enriched_data = []

# Step 2: Read all JSON files and extract the required fields
for file_name in os.listdir(enriched_dir):
    if file_name.endswith('.json'):
        tmdb_id = file_name.split('.')[0]

        # Read the JSON data
        with open(os.path.join(enriched_dir, file_name), 'r', encoding='utf-8') as f:
            movie_data = json.load(f)

        # Extract required fields
        title = movie_data.get("title", "")
        budget = movie_data.get("budget", None)
        imdb_id = movie_data.get("imdb_id", "")

        # origin_country from "production_countries" field
        production_countries = movie_data.get("production_countries", [])
        origin_country = ", ".join([c.get("name", "") for c in production_countries])

        original_language = movie_data.get("original_language", "")
        original_title = movie_data.get("original_title", "")
        overview = movie_data.get("overview", "")
        popularity = movie_data.get("popularity", None)
        release_date = movie_data.get("release_date", "")
        runtime = movie_data.get("runtime", None)
        tagline = movie_data.get("tagline", "")
        vote_average = movie_data.get("vote_average", None)
        vote_count = movie_data.get("vote_count", None)
        
        # Append extracted fields
        enriched_data.append({
            "tmdbId": tmdb_id,
            "title": title,
            "budget": budget,
            "imdb_id": imdb_id,
            "origin_country": origin_country,
            "original_language": original_language,
            "original_title": original_title,
            "overview": overview,
            "popularity": popularity,
            "release_date": release_date,
            "runtime": runtime,
            "tagline": tagline,
            "vote_average": vote_average,
            "vote_count": vote_count
        })

# Create a DataFrame from the enriched data
enriched_df = pd.DataFrame(enriched_data)

# Step 3: Escape text fields and handle line breaks
def escape_text_fields(df):
    text_columns = df.select_dtypes(include=['object']).columns
    for column in text_columns:
        # Escape line breaks and ensure proper quoting
        df[column] = df[column].apply(lambda x: str(x).replace('\n', ' ').replace('\r', ' ') if isinstance(x, str) else x)
    return df

# Escape text fields
enriched_df = escape_text_fields(enriched_df)

# Convert tmdbId to numeric if possible (links.csv often stores it as float)
enriched_df['tmdbId'] = pd.to_numeric(enriched_df['tmdbId'], errors='coerce')

# Step 4: Save the enriched data to movies_enriched.csv
output_file = "data/movies_enriched_32m.csv"
enriched_df.to_csv(output_file, index=False, quoting=csv.QUOTE_ALL, encoding='utf-8')
print(f"Enriched data saved to {output_file}")
# Out:
# Enriched data saved to data/movies_enriched_32m.csv

# %% [markdown]
# Check the created csv file:

# %%
import pandas as pd

# Load the CSV file
file_path = 'data/movies_enriched_32m.csv'  # Adjust to your actual file path
df = pd.read_csv(file_path, on_bad_lines='skip')

# Step 1: Check Numerical Columns for Invalid Values
numerical_columns = ['tmdbId', 'budget', 'runtime', 'vote_count', 'vote_average']

def check_numerical_columns(df, numerical_columns):
    invalid_values = {}
    for column in numerical_columns:
        # Try converting to numeric, invalid entries will become NaN
        converted = pd.to_numeric(df[column], errors='coerce')
        # Identify non-numeric entries (i.e., original values that became NaN)
        non_numeric_mask = converted.isna() & ~df[column].isna()
        non_numeric_values = df.loc[non_numeric_mask, column].unique()
        # Count non-numeric values
        non_numeric_count = len(non_numeric_values)
        invalid_values[column] = {
            'Original NaN': df[column].isna().sum(),
            'Non-Numeric Count': non_numeric_count,
            'Non-Numeric Values': non_numeric_values.tolist()
        }
    return invalid_values

numerical_issues = check_numerical_columns(df, numerical_columns)
print("Numerical Column Issues:")
for column, issues in numerical_issues.items():
    print(f"{column}: {issues}")

# Step 2: Impute Missing (NaN) Values with Column Mean
def impute_missing_values(df, numerical_columns):
    for column in numerical_columns:
        if column in df.columns:
            # Convert column to numeric, coercing invalid entries to NaN
            df[column] = pd.to_numeric(df[column], errors='coerce')
            # Replace NaN with the column mean
            mean_value = df[column].mean()
            df[column] = df[column].fillna(mean_value)
    return df

df = impute_missing_values(df, numerical_columns)
print("Missing values imputed with column means.")

# Step 3: Escape Non-Numerical Fields (Text) Appropriately
# def escape_text_fields(df):
#     text_columns = df.select_dtypes(include=['object']).columns
#     for column in text_columns:
#         df[column] = df[column].apply(lambda x: f'"{x}"' if isinstance(x, str) else x)
#     return df

# Escape text fields as per CSV standard
#df_escaped = escape_text_fields(df)

# Save the cleaned and escaped data to a new file
output_file = 'data/movies_enriched_32m_cleaned.csv'
df.to_csv(output_file, index=False, quoting=1)  # quoting=1 ensures all non-numeric fields are properly escaped
print(f"Cleaned and escaped data saved to: {output_file}")
# Out:
# Numerical Column Issues:
# tmdbId: {'Original NaN': 0, 'Non-Numeric Count': 0, 'Non-Numeric Values': []}
# budget: {'Original NaN': 0, 'Non-Numeric Count': 0, 'Non-Numeric Values': []}
# runtime: {'Original NaN': 0, 'Non-Numeric Count': 0, 'Non-Numeric Values': []}
# vote_count: {'Original NaN': 0, 'Non-Numeric Count': 0, 'Non-Numeric Values': []}
# vote_average: {'Original NaN': 0, 'Non-Numeric Count': 0, 'Non-Numeric Values': []}
# Missing values imputed with column means.
# Cleaned and escaped data saved to: data/movies_enriched_32m_cleaned.csv

# %% [markdown]
# Now join the movies_enriched.csv with the movies.csv.

# %%
import os
import json
import pandas as pd

# Step 1: Read links.csv
links_df = pd.read_csv('data/ml-32m/links.csv')

# Step 4: Read the newly created movies_enriched.csv
movies_enriched_df = pd.read_csv("data/movies_enriched_32m_cleaned.csv")

# Step 5: Read movies.csv
movies_df = pd.read_csv("data/ml-32m/movies.csv")

# Step 6: Join movies.csv and movies_enriched.csv via movieId, tmdbId from links.csv

# Convert movieId in links to int if needed
links_df['movieId'] = pd.to_numeric(links_df['movieId'], errors='coerce')
links_df['tmdbId'] = pd.to_numeric(links_df['tmdbId'], errors='coerce')

# Merge links_df with movies_enriched_df on tmdbId first
links_enriched_merged = pd.merge(links_df, movies_enriched_df, on='tmdbId', how='left')

# Now merge the above result with movies_df on movieId
final_merged_df = pd.merge(movies_df, links_enriched_merged, on='movieId', how='left')

# Step 7: Save the final merged DataFrame
final_merged_df.to_csv("data/ml-32m/movies_with_enriched_data.csv", index=False)

print("Merging complete! The final file is: movies_with_enriched_data.csv")
# Out:
# Merging complete! The final file is: movies_with_enriched_data.csv
