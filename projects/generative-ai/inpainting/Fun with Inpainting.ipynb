# %% [markdown]
# In this project we will build a nice web app that allows you to swap out the background of a subject and substitute it with an image generated by Stable Diffusion through a text prompt:
#
# ![image.png](attachment:image.png)
#
# Let's start by importing what we need:

# %%
from PIL import Image
import requests
from transformers import SamModel, SamProcessor
from diffusers import DiffusionPipeline, AutoPipelineForText2Image, AutoPipelineForInpainting
from diffusers.utils import load_image, make_image_grid

import torch
import numpy as np
from matplotlib import pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## SAM
#
# Complete the following cell by loading the pretrained SAM from Facebook/Meta. Remember to:
#
# 1. Move the model to the GPU by adding `.to("cuda")`
# 2. Add the option `torch_dtype=torch.float16` to your call of AutoPipelineForInpainting.from_pretrained
#
# This cell might take a couple of minutes to load.

# %%
# Load the SAM model as we have seen in the class
# Remeber to load it on the GPU by adding .to("cuda")
# at the end
model = SamModel.from_pretrained("facebook/sam-vit-large")
model.to(device)  # Ensure the model is loaded onto the GPU

# Load the SamProcessor using the facebook/sam-vit-base
# checkpoint
processor = SamProcessor.from_pretrained("facebook/sam-vit-large")

# %% [markdown]
# ### Get the mask
#
# Now that you have loaded SAM, complete the following function that uses SAM to produce a segmentation mask:

# %%
def plot_predicted_masks(image, predicted_masks, input_points=None):
    """
    Plots all predicted masks overlaid on the input image with optional input points.

    Args:
    - image: Original PIL Image.
    - predicted_masks: Tensor or numpy array of shape (num_masks, height, width).
    - input_points: List of tuples or numpy array of shape (num_points, 2), where each point is (x, y).
    """

    # Convert the image to a NumPy array
    image_np = np.array(image)
    
    # Number of masks
    num_masks = predicted_masks.shape[0]
    
    # Ensure the mask is 2D for visualization
    for i in range(num_masks):
        mask = predicted_masks[i]  # Shape (height, width)        
        plt.figure(figsize=(8, 8))
        plt.imshow(image_np)  # Display the original image
        plt.imshow(mask, alpha=0.5, cmap="jet")  # Overlay mask with transparency
        
        # If input points are provided, plot them
        if input_points is not None:
            input_points = np.array(input_points)  # Ensure points are in numpy array format
            plt.scatter(input_points[:, 0], input_points[:, 1], color="red", s=50, label="Input Points")
            plt.legend()

        plt.title(f"Predicted Mask {i+1}")
        plt.axis("on")
        plt.show()

        
def mask_to_rgb(mask):
    """
    Transforms a binary mask into an RGBA image for visualization
    """
    
    bg_transparent = np.zeros(mask.shape + (4, ), dtype=np.uint8)
    
    # Color the area we will replace in green
    # (this vector is [Red, Green, Blue, Alpha])
    bg_transparent[mask == 1] = [0, 255, 0, 127]
    
    return bg_transparent

@torch.no_grad()
def get_processed_inputs(image, input_points):
    # Use the processor to generate the right inputs
    # for SAM
    # Use "image" as your image
    # Use 'input_points' as your input_points,
    # and remember to use the option return_tensors='pt'
    # Also, remember to add .to("cuda") at the end
    inputs = processor(images=image, return_tensors="pt").to(device)  # Ensure tensors are moved to GPU
    
    input_points_batch = np.expand_dims(input_points, axis=0)
    input_points_pt = torch.tensor(input_points_batch, device=device)
    inputs.update({"input_points": input_points_pt})

    # Call SAM
    outputs = model(**inputs)
    
    #predicted_masks = outputs.pred_masks.squeeze().cpu().numpy()

    #original_size = (512, 512)  # Original image size
    #resized_masks = [
    #    np.array(Image.fromarray(mask).resize(original_size, resample=Image.NEAREST))
    #    for mask in predicted_masks
    #]

    #plot_predicted_masks(image, predicted_masks=np.array(resized_masks), input_points=input_points[0][0])

    # Now let's post process the outputs of SAM to obtain the masks
    masks = processor.image_processor.post_process_masks(
       outputs.pred_masks.cpu(), 
       inputs["original_sizes"].cpu(), 
       inputs["reshaped_input_sizes"].cpu()
    )
    
    # Here we select the mask with the highest score
    # as the mask we will use. You can experiment with also
    # other selection criteria, for example the largest mask
    # instead of the most confident mask
    best_mask = masks[0][0][outputs.iou_scores.argmax()] 

    # NOTE: we invert the mask by using the ~ operator because
    # so that the subject pixels will have a value of 0 and the
    # background pixels a value of 1. This will make it more convenient
    # to infill the background
    return ~best_mask.cpu().numpy()

# Save the mask as an image
def save_mask_as_image(mask, filename="mask.png"):
    # Ensure mask is in uint8 format and scaled properly
    if mask.dtype != np.uint8:
        mask = (mask.astype(np.uint8) * 255)  # Convert boolean mask to 0/255
    mask_image = Image.fromarray(mask)
    mask_image.save(filename)
    print(f"Mask saved to {filename}")

# Load the mask from an image
def load_mask_from_image(filename="mask.png"):
    mask_image = Image.open(filename)
    mask = np.array(mask_image)
    return mask

# %% [markdown]
# Now let's test what we have done so far. By executing this cell you should get a visualization of the mask for the following car:
#
# <img src='car.png' width="200px"></img>
#
# Let's see what happens in this cell:
# 1. We open the image of the car and **we resize it to 512 by 512 pixels** (a square image). This makes things simpler for this project
# 2. We define a few points on the image that indicate where the car is
# 3. We use the function we have defined to generate a mask using SAM
# 4. We visualize the mask
#
# The mask should look like this:
#
# ![image-2.png](attachment:image-2.png)
#
# If it doesn't or you get errors, double check the code you have completed above and fix it before moving on.

# %%
raw_image = Image.open("car.png").convert("RGB").resize((512, 512))

# The guiding coordinates for the mask to be inpainted (must be selected manually and carefully)
input_points = [[[160, 227], [85, 296], [162, 316], [435, 286], [279, 287], [430, 238]]]

mask = get_processed_inputs(raw_image, input_points)

# Save the mask as an image
#save_mask_as_image(mask, filename="mask.png")

# Display the mask
Image.fromarray(mask_to_rgb(mask)).resize((128, 128))
# Out:
# sizes: (512, 512)
# mask shape: (512, 512)
# mask shape: (512, 512)
# mask shape: (512, 512)
# Mask saved to mask.png

# %% [markdown]
# ## Inpainting
#
# Now that we have completed the SAM setup, let's move to the inpainting setup.
#
# Let's start by loading our inpainting pipeline. We will use the `diffusers/stable-diffusion-xl-1.0-inpainting-0.1` pretrained model and the `AutoPipelineForInpainting` as we have seen in our `diffusers` demo in Lesson 5.
#
# Complete the following code and run it (it might take a few minutes to run):
#
# > **NOTE**: you will probably see a warning similar to ``The config attributes {'decay'...``. Please ignore it. It is a warning generated by the diffusers library that does not constitute a problem for our application

# %%
# Load the AutoPipelineForInpainting pipeline 
# (remember the diffusers demo in lesson 5)
# The checkpoint we want to use is 
# "diffusers/stable-diffusion-xl-1.0-inpainting-0.1"
# Remember to add torch_dtype=torch.float16 as an option
pipeline = AutoPipelineForInpainting.from_pretrained(
    "diffusers/stable-diffusion-xl-1.0-inpainting-0.1", torch_dtype=torch.float16
)

pipeline = pipeline.to(device)

# This will make it more efficient on our hardware
#pipeline.enable_model_cpu_offload()
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# The config attributes {'decay': 0.9999, 'inv_gamma': 1.0, 'min_decay': 0.0, 'optimization_step': 37000, 'power': 0.6666666666666666, 'update_after_step': 0, 'use_ema_warmup': False} were passed to UNet2DConditionModel, but are not expected and will be ignored. Please verify your config.json configuration file.

# %%
print(pipeline.unet.device)  # Should show 'cuda'
print(pipeline.vae.device)   # Should show 'cuda'
# Out:
# cuda:0
# cuda:0

# %% [markdown]
# Now complete the following function that gets in input:
# 1. The raw image
# 2. The mask generated by SAM (a numpy array)
# 3. The text prompt for the infill
# 4. An optional negative prompt
# 5. An optional seed for repeatibility
# 6. The Classifier-Free Guidance Scale (CFGS). If you don't remember what this is, refer to the Text Conditioning explanation in Lesson 5

# %%
@torch.no_grad()
def inpaint(raw_image, input_mask, prompt, negative_prompt=None, seed=74294536, cfgs=7):
    mask_image = Image.fromarray(input_mask)

    rand_gen = torch.manual_seed(seed)
    
    # Use the pipeline we have created in the previous cell
    # Use "prompt" as prompt, 
    # "negative_prompt" as the negative prompt,
    # raw_image as the image,
    # mask_image as the mask_image,
    # rand_gen as the generator and
    # cfgs as the guidance_scale
    
    image = pipeline(
        prompt=prompt, negative_prompt=negative_prompt, image=raw_image, mask_image=mask_image, generator=rand_gen, guidance_scale=cfgs
    ).images[0]
    
    return image

# %% [markdown]
# Let's test our inpainting on the mask we have obtained earlier with SAM:

# %%
loaded_mask = load_mask_from_image("mask.png")
raw_image = Image.open("car.png").convert("RGB").resize((512, 512))

prompt = "a car driving on Mars. Studio lights, 1970s"
negative_prompt = "artifacts, low quality, distortion"

image = inpaint(raw_image, loaded_mask, prompt, negative_prompt)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 7
#       4 prompt = "a car driving on Mars. Studio lights, 1970s"
#       5 negative_prompt = "artifacts, low quality, distortion"
# ----> 7 image = inpaint(raw_image, loaded_mask, prompt, negative_prompt)
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# Cell In[8], line 17, in inpaint(raw_image, input_mask, prompt, negative_prompt, seed, cfgs)
#       7 rand_gen = torch.manual_seed(seed)
#       9 # Use the pipeline we have created in the previous cell
#      10 # Use "prompt" as prompt,
#      11 # "negative_prompt" as the negative prompt,
#    (...)
#      14 # rand_gen as the generator and
#      15 # cfgs as the guidance_scale
# ---> 17 image = pipeline(
#      18     prompt=prompt, negative_prompt=negative_prompt, image=raw_image, mask_image=mask_image, generator=rand_gen, guidance_scale=cfgs
#      19 ).images[0]
#      21 return image
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/diffusers/pipelines/stable_diffusion_xl/pipeline_stable_diffusion_xl_inpaint.py:1394, in StableDiffusionXLInpaintPipeline.__call__(self, prompt, prompt_2, image, mask_image, masked_image_latents, height, width, padding_mask_crop, strength, num_inference_steps, timesteps, sigmas, denoising_start, denoising_end, guidance_scale, negative_prompt, negative_prompt_2, num_images_per_prompt, eta, generator, latents, prompt_embeds, negative_prompt_embeds, pooled_prompt_embeds, negative_pooled_prompt_embeds, ip_adapter_image, ip_adapter_image_embeds, output_type, return_dict, cross_attention_kwargs, guidance_rescale, original_size, crops_coords_top_left, target_size, negative_original_size, negative_crops_coords_top_left, negative_target_size, aesthetic_score, negative_aesthetic_score, clip_skip, callback_on_step_end, callback_on_step_end_tensor_inputs, **kwargs)
#    1384 # 3. Encode input prompt
#    1385 text_encoder_lora_scale = (
#    1386     self.cross_attention_kwargs.get("scale", None) if self.cross_attention_kwargs is not None else None
#    1387 )
#    1389 (
#    1390     prompt_embeds,
#    1391     negative_prompt_embeds,
#    1392     pooled_prompt_embeds,
#    1393     negative_pooled_prompt_embeds,
# -> 1394 ) = self.encode_prompt(
#    1395     prompt=prompt,
#    1396     prompt_2=prompt_2,
#    1397     device=device,
#    1398     num_images_per_prompt=num_images_per_prompt,
#    1399     do_classifier_free_guidance=self.do_classifier_free_guidance,
#    1400     negative_prompt=negative_prompt,
#    1401     negative_prompt_2=negative_prompt_2,
#    1402     prompt_embeds=prompt_embeds,
#    1403     negative_prompt_embeds=negative_prompt_embeds,
#    1404     pooled_prompt_embeds=pooled_prompt_embeds,
#    1405     negative_pooled_prompt_embeds=negative_pooled_prompt_embeds,
#    1406     lora_scale=text_encoder_lora_scale,
#    1407     clip_skip=self.clip_skip,
#    1408 )
#    1410 # 4. set timesteps
#    1411 def denoising_value_valid(dnv):
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/diffusers/pipelines/stable_diffusion_xl/pipeline_stable_diffusion_xl_inpaint.py:534, in StableDiffusionXLInpaintPipeline.encode_prompt(self, prompt, prompt_2, device, num_images_per_prompt, do_classifier_free_guidance, negative_prompt, negative_prompt_2, prompt_embeds, negative_prompt_embeds, pooled_prompt_embeds, negative_pooled_prompt_embeds, lora_scale, clip_skip)
#     528     removed_text = tokenizer.batch_decode(untruncated_ids[:, tokenizer.model_max_length - 1 : -1])
#     529     logger.warning(
#     530         "The following part of your input was truncated because CLIP can only handle sequences up to"
#     531         f" {tokenizer.model_max_length} tokens: {removed_text}"
#     532     )
# --> 534 prompt_embeds = text_encoder(text_input_ids.to(device), output_hidden_states=True)
#     536 # We are only ALWAYS interested in the pooled output of the final text encoder
#     537 pooled_prompt_embeds = prompt_embeds[0]
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py:1050, in CLIPTextModel.forward(self, input_ids, attention_mask, position_ids, output_attentions, output_hidden_states, return_dict)
#    1031 r"""
#    1032 Returns:
#    1033
#    (...)
#    1046 >>> pooled_output = outputs.pooler_output  # pooled (EOS token) states
#    1047 ```"""
#    1048 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1050 return self.text_model(
#    1051     input_ids=input_ids,
#    1052     attention_mask=attention_mask,
#    1053     position_ids=position_ids,
#    1054     output_attentions=output_attentions,
#    1055     output_hidden_states=output_hidden_states,
#    1056     return_dict=return_dict,
#    1057 )
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py:954, in CLIPTextTransformer.forward(self, input_ids, attention_mask, position_ids, output_attentions, output_hidden_states, return_dict)
#     950 if attention_mask is not None and not self._use_flash_attention_2:
#     951     # [bsz, seq_len] -> [bsz, 1, tgt_seq_len, src_seq_len]
#     952     attention_mask = _prepare_4d_attention_mask(attention_mask, hidden_states.dtype)
# --> 954 encoder_outputs = self.encoder(
#     955     inputs_embeds=hidden_states,
#     956     attention_mask=attention_mask,
#     957     causal_attention_mask=causal_attention_mask,
#     958     output_attentions=output_attentions,
#     959     output_hidden_states=output_hidden_states,
#     960     return_dict=return_dict,
#     961 )
#     963 last_hidden_state = encoder_outputs[0]
#     964 last_hidden_state = self.final_layer_norm(last_hidden_state)
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py:877, in CLIPEncoder.forward(self, inputs_embeds, attention_mask, causal_attention_mask, output_attentions, output_hidden_states, return_dict)
#     869     layer_outputs = self._gradient_checkpointing_func(
#     870         encoder_layer.__call__,
#     871         hidden_states,
#    (...)
#     874         output_attentions,
#     875     )
#     876 else:
# --> 877     layer_outputs = encoder_layer(
#     878         hidden_states,
#     879         attention_mask,
#     880         causal_attention_mask,
#     881         output_attentions=output_attentions,
#     882     )
#     884 hidden_states = layer_outputs[0]
#     886 if output_attentions:
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py:608, in CLIPEncoderLayer.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     605 residual = hidden_states
#     607 hidden_states = self.layer_norm1(hidden_states)
# --> 608 hidden_states, attn_weights = self.self_attn(
#     609     hidden_states=hidden_states,
#     610     attention_mask=attention_mask,
#     611     causal_attention_mask=causal_attention_mask,
#     612     output_attentions=output_attentions,
#     613 )
#     614 hidden_states = residual + hidden_states
#     616 residual = hidden_states
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/anaconda3/envs/pytorch_env/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py:540, in CLIPSdpaAttention.forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     537     value_states = value_states.contiguous()
#     539 # CLIP text model uses both `causal_attention_mask` and `attention_mask` sequentially.
# --> 540 attn_output = torch.nn.functional.scaled_dot_product_attention(
#     541     query_states,
#     542     key_states,
#     543     value_states,
#     544     attn_mask=attn_mask,
#     545     dropout_p=self.dropout if self.training else 0.0,
#     546     scale=self.scale,
#     547 )
#     549 attn_output = attn_output.transpose(1, 2)
#     550 attn_output = attn_output.reshape(bsz, tgt_len, embed_dim)
#
# RuntimeError: cuDNN Frontend error: [cudnn_frontend] Error: No execution plans support the graph.

# %% [markdown]
# Let's have a look at what we have produced:

# %%
fig = make_image_grid([raw_image, Image.fromarray(mask_to_rgb(mask)), image.resize((512, 512))], rows=1, cols=3)
fig

# %% [markdown]
# ## Interactive app
#
# To make things a bit more fun, we have prepared an interactive app for you that uses the code you have completed and allow you to upload an image, run SAM, and generate the new background through a text prompt.
#
# Simply execute the following cell. The output will contain a preview of the app: **DO NOT USE IT**. Instead, you will also see a link similar to this:
#
# ![image.png](attachment:image.png)
#
# Click on the second link (the public URL), from there you will be able to use the app much more comfortably.
#
# > NOTE: if for any reason you need to stop the app, click on the stop icon of the jupyter interface: ![image-3.png](attachment:image-3.png)  then **execute the next cell containing the code `my_app.close`**

# %%
import app

# %%
my_app = app.generate_app(get_processed_inputs, inpaint)

# %%
my_app.close()
